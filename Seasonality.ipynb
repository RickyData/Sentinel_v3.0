# %%
import pandas as pd
import numpy as np

# %%
file =pd.read_csv('EURAUD1440.csv', names=["Date", "Time", "Open", "High", "Low", "Close", "Volume"])
file.head()
# Out:
#          Date   Time    Open    High     Low   Close  Volume
# 0  2004.06.17  00:00  1.7429  1.7763  1.7408  1.7687   10497
# 1  2004.06.18  00:00  1.7686  1.7686  1.7508  1.7618    6098
# 2  2004.06.21  00:00  1.7576  1.7634  1.7492  1.7539    6322
# 3  2004.06.22  00:00  1.7537  1.7643  1.7512  1.7613    6697
# 4  2004.06.23  00:00  1.7612  1.7662  1.7533  1.7567    7000

# %%
file.drop(file.loc[:, ["Time", "Open", "High", "Low", "Volume"]], inplace=True, axis=1)
file.head()
# Out:
#          Date   Close
# 0  2004.06.17  1.7687
# 1  2004.06.18  1.7618
# 2  2004.06.21  1.7539
# 3  2004.06.22  1.7613
# 4  2004.06.23  1.7567

# %%
file.dtypes

# %%
file['Date'] = pd.to_datetime(file['Date'])
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3701 entries, 0 to 3700
# Data columns (total 2 columns):
# Date     3701 non-null datetime64[ns]
# Close    3701 non-null float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 57.9 KB

# %%
file['Year'] = file.Date.dt.year
file['Week_day'] =file.Date.dt.weekday
file['Week_year'] = file.Date.dt.weekofyear
file['Returns'] = np.log(file.Close/file.Close.shift(1)) 
file.head()
# Out:
#         Date   Close  Year  Week_day  Week_year   Returns
# 0 2004-06-17  1.7687  2004         3         25       NaN
# 1 2004-06-18  1.7618  2004         4         25 -0.003909
# 2 2004-06-21  1.7539  2004         0         26 -0.004494
# 3 2004-06-22  1.7613  2004         1         26  0.004210
# 4 2004-06-23  1.7567  2004         2         26 -0.002615

# %%
file.head(20)
# Out:
#          Date   Close  Year  Week_day  Week_year   Returns
# 0  2004-06-17  1.7687  2004         3         25       NaN
# 1  2004-06-18  1.7618  2004         4         25 -0.003909
# 2  2004-06-21  1.7539  2004         0         26 -0.004494
# 3  2004-06-22  1.7613  2004         1         26  0.004210
# 4  2004-06-23  1.7567  2004         2         26 -0.002615
# 5  2004-06-24  1.7401  2004         3         26 -0.009494
# 6  2004-06-25  1.7372  2004         4         26 -0.001668
# 7  2004-06-28  1.7391  2004         0         27  0.001093
# 8  2004-06-29  1.7474  2004         1         27  0.004761
# 9  2004-06-30  1.7450  2004         2         27 -0.001374
# 10 2004-07-01  1.7235  2004         3         27 -0.012397
# 11 2004-07-02  1.7258  2004         4         27  0.001334
# 12 2004-07-05  1.7254  2004         0         28 -0.000232
# 13 2004-07-06  1.7204  2004         1         28 -0.002902
# 14 2004-07-07  1.7105  2004         2         28 -0.005771
# 15 2004-07-08  1.7179  2004         3         28  0.004317
# 16 2004-07-09  1.7185  2004         4         28  0.000349
# 17 2004-07-12  1.7063  2004         0         29 -0.007125
# 18 2004-07-13  1.7007  2004         1         29 -0.003287
# 19 2004-07-14  1.7086  2004         2         29  0.004634

# %%
present = file.loc[file['Week_year']== 39,]
#bulls = present.loc[present['Direction'] == 'Bull',:]
# 3181 2016-09-26  1.47333  2016         0         39  0.002195
# 3182 2016-09-27  1.46218  2016         1         39 -0.007597
# 3183 2016-09-28  1.45788  2016         2         39 -0.002945
# 3184 2016-09-29  1.46896  2016         3         39  0.007571
# 3185 2016-09-30  1.46691  2016         4         39 -0.001397
# 3441 2017-09-25  1.49268  2017         0         39 -0.008532
# 3442 2017-09-26  1.49480  2017         1         39  0.001419
# 3443 2017-09-27  1.49617  2017         2         39  0.000916
# 3444 2017-09-28  1.49987  2017         3         39  0.002470
# 3445 2017-09-29  1.50798  2017         4         39  0.005393
# 3699 2018-09-24  1.61963  2018         0         39  0.004307
# 3700 2018-09-25  1.62296  2018         1         39  0.002054
#
# [72 rows x 6 columns]

# %%
len(present)
# Out:
# 72

# %%
a
# Out:
# C:\Users\Siseng Consulting\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
present
# Out:
#            Date    Close  Year  Week_day  Week_year   Returns     lag_1  \
# 67   2004-09-20  1.73710  2004         0         39 -0.004709       NaN
# 68   2004-09-21  1.75090  2004         1         39  0.007913       NaN
# 69   2004-09-22  1.73380  2004         2         39 -0.009814       NaN
# 70   2004-09-23  1.71890  2004         3         39 -0.008631       NaN
# 71   2004-09-24  1.71680  2004         4         39 -0.001222       NaN
# 330  2005-09-26  1.59510  2005         0         39  0.003077 -0.004709
# 331  2005-09-27  1.58840  2005         1         39 -0.004209  0.007913
# 332  2005-09-28  1.58640  2005         2         39 -0.001260 -0.009814
# 333  2005-09-29  1.58240  2005         3         39 -0.002525 -0.008631
# 334  2005-09-30  1.57760  2005         4         39 -0.003038 -0.001222
# 587  2006-09-25  1.69010  2006         0         39 -0.007897  0.003077
# 588  2006-09-26  1.68750  2006         1         39 -0.001540 -0.004209
# 589  2006-09-27  1.69000  2006         2         39  0.001480 -0.001260
# 590  2006-09-28  1.69550  2006         3         39  0.003249 -0.002525
# 591  2006-09-29  1.69830  2006         4         39  0.001650 -0.003038
# 844  2007-09-24  1.62170  2007         0         39 -0.001971 -0.007897
# 845  2007-09-25  1.61880  2007         1         39 -0.001790 -0.001540
# 846  2007-09-26  1.61150  2007         2         39 -0.004520  0.001480
# 847  2007-09-27  1.60790  2007         3         39 -0.002236  0.003249
# 848  2007-09-28  1.60630  2007         4         39 -0.000996  0.001650
# 1100 2008-09-22  1.75370  2008         0         39  0.011066 -0.001971
# 1101 2008-09-23  1.75900  2008         1         39  0.003018 -0.001790
# 1102 2008-09-24  1.75280  2008         2         39 -0.003531 -0.004520
# 1103 2008-09-25  1.75130  2008         3         39 -0.000856 -0.002236
# 1104 2008-09-26  1.75810  2008         4         39  0.003875 -0.000996
# 1358 2009-09-21  1.70140  2009         0         39  0.003533  0.011066
# 1359 2009-09-22  1.69240  2009         1         39 -0.005304  0.003018
# 1360 2009-09-23  1.69530  2009         2         39  0.001712 -0.003531
# 1361 2009-09-24  1.69350  2009         3         39 -0.001062 -0.000856
# 2921 -0.009221  0.003041  0.007584  0.007444 -0.002947  0.006453  0.002442
# 2922  0.007836 -0.009221  0.003041  0.007584  0.007444 -0.002947  0.006453
# 3181 -0.002596  0.007836 -0.009221  0.003041  0.007584  0.007444 -0.002947
# 3182 -0.000924 -0.002596  0.007836 -0.009221  0.003041  0.007584  0.007444
# 3183  0.000159 -0.000924 -0.002596  0.007836 -0.009221  0.003041  0.007584
# 3184  0.017667  0.000159 -0.000924 -0.002596  0.007836 -0.009221  0.003041
# 3185  0.001127  0.017667  0.000159 -0.000924 -0.002596  0.007836 -0.009221
# 3441 -0.003604  0.001127  0.017667  0.000159 -0.000924 -0.002596  0.007836
# 3442  0.002195 -0.003604  0.001127  0.017667  0.000159 -0.000924 -0.002596
# 3443 -0.007597  0.002195 -0.003604  0.001127  0.017667  0.000159 -0.000924
# 3444 -0.002945 -0.007597  0.002195 -0.003604  0.001127  0.017667  0.000159
# 3445  0.007571 -0.002945 -0.007597  0.002195 -0.003604  0.001127  0.017667
# 3699 -0.001397  0.007571 -0.002945 -0.007597  0.002195 -0.003604  0.001127
# 3700 -0.008532 -0.001397  0.007571 -0.002945 -0.007597  0.002195 -0.003604
#
# [72 rows x 14 columns]

# %%
op_1 = bulls.loc[bulls['Week_day'] == 'Tuesday', :]
op_1

# %%
op_2 = bears.loc[bears['Week_day'] == 'Friday', :]
op_2

# %%
bull_Confidence =len(op_1)/(len(op_1) + len(op_2))
bull_Confidence

# %%
bear_Confidence = len(op_2)/(len(op_2) + len(op_1))
bear_Confidence

# %%
file.head()

# %%
import matplotlib.pyplot as plt

# %%
pivott = file.pivot_table(index = 'Week_day', columns = ['Direction','Week_year'], values='Returns', aggfunc='count')

# %%
raw_data = {'student_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze', 'Jacon', 'Ryaner', 'Sone', 'Sloan', 'Piger', 'Riani', 'Ali'], 
        'test_score': [76, 88, 84, 67, 53, 96, 64, 91, 77, 73, 52, np.NaN]}
df = pd.DataFrame(raw_data, columns = ['student_name', 'test_score'])

# %%
# Create a list to store the data
grades = []

# For each row in the column,
for row in df['test_score']:
    # if more than a value,
    if row > 95:
        # Append a letter grade
        grades.append('A')
    # else, if more than a value,
    elif row > 90:
        # Append a letter grade
        grades.append('A-')
    # else, if more than a value,
    elif row > 85:
        # Append a letter grade
        grades.append('B')
    # else, if more than a value,
    elif row > 80:
        # Append a letter grade
        grades.append('B-')
    # else, if more than a value,
    elif row > 75:
        # Append a letter grade
        grades.append('C')
    # else, if more than a value,
    elif row > 70:
        # Append a letter grade
        grades.append('C-')
    # else, if more than a value,
    elif row > 65:
        # Append a letter grade
        grades.append('D')
    # else, if more than a value,
    elif row > 60:
        # Append a letter grade
        grades.append('D-')
    # otherwise,
    else:
        # Append a failing grade
        grades.append('Failed')
        
# Create a column from the list
df['grades'] = grades

# %%
# View the new dataframe
df

# %%
import keras
